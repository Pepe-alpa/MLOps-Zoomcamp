# %% [markdown]
# ## Homework
#
# The goal of this homework is to get familiar with MLflow, the tool for experiment tracking and
# model management.
#
#
# ## Q1. Install MLflow
#
# To get started with MLflow you'll need to install the MLflow Python package.
#
# For this we recommend creating a separate Python environment, for example, you can use [conda environments](https://docs.conda.io/projects/conda/en/latest/user-guide/getting-started.html#managing-envs), and then install the package there with `pip` or `conda`.
#
# Once you installed the package, run the command `mlflow --version` and check the output.
#
# What's the version that you have?

# %%
! mlflow --version
# Out:
# mlflow, version 2.22.0

# %% [markdown]
# ## Q2. Download and preprocess the data
#
# We'll use the Yellow Taxi Trip Records dataset to predict the duration of each trip.
#
# Download the data for January, February and March 2023 in parquet format from [here](https://www1.nyc.gov/site/tlc/about/tlc-trip-record-data.page).
#
# Use the script `preprocess_data.py` located in the folder [`homework`](homework) to preprocess the data.
#
# The script will:
#
# * load the data from the folder `<TAXI_DATA_FOLDER>` (the folder where you have downloaded the data),
# * fit a `DictVectorizer` on the training set (January 2023 data),
# * save the preprocessed datasets and the `DictVectorizer` to disk.
#
# Your task is to download the datasets and then execute this command:
#
# ```
# python preprocess_data.py --raw_data_path <TAXI_DATA_FOLDER> --dest_path ./output
# ```
#
# Tip: go to `02-experiment-tracking/homework/` folder before executing the command and change the value of `<TAXI_DATA_FOLDER>` to the location where you saved the data.
#
# How many files were saved to `OUTPUT_FOLDER`?
#
# * 1
# * 3
# * 4
# * 7

# %%
! python preprocess_data.py --raw_data_path data/ --dest_path ./output

# %% [markdown]
# 4

# %% [markdown]
# ## Q3. Train a model with autolog
#
# We will train a `RandomForestRegressor` (from Scikit-Learn) on the taxi dataset.
#
# We have prepared the training script `train.py` for this exercise, which can be also found in the folder [`homework`](homework).
#
# The script will:
#
# * load the datasets produced by the previous step,
# * train the model on the training set,
# * calculate the RMSE score on the validation set.
#
# Your task is to modify the script to enable **autologging** with MLflow, execute the script and then launch the MLflow UI to check that the experiment run was properly tracked.
#
# Tip 1: don't forget to wrap the training code with a `with mlflow.start_run():` statement as we showed in the videos.
#
# Tip 2: don't modify the hyperparameters of the model to make sure that the training will finish quickly.
#
# What is the value of the `min_samples_split` parameter:
#
# * 2
# * 4
# * 8
# * 10

# %%
# !python train.py --data_path ./output

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Q4. Launch the tracking server locally
#
# Now we want to manage the entire lifecycle of our ML model. In this step, you'll need to launch a tracking server. This way we will also have access to the model registry.
#
# Your task is to:
#
# * launch the tracking server on your local machine,
# * select a SQLite db for the backend store and a folder called `artifacts` for the artifacts store.
#
# You should keep the tracking server running to work on the next two exercises that use the server.
#
# In addition to `backend-store-uri`, what else do you need to pass to properly configure the server?
#
# * `default-artifact-root`
# * `serve-artifacts`
# * `artifacts-only`
# * `artifacts-destination`

# %% [markdown]
# default-artifact-root

# %% [markdown]
# ## Q5. Tune model hyperparameters
#
# Now let's try to reduce the validation error by tuning the hyperparameters of the `RandomForestRegressor` using `hyperopt`.
# We have prepared the script `hpo.py` for this exercise.
#
# Your task is to modify the script `hpo.py` and make sure that the validation RMSE is logged to the tracking server for each run of the hyperparameter optimization (you will need to add a few lines of code to the `objective` function) and run the script without passing any parameters.
#
# After that, open UI and explore the runs from the experiment called `random-forest-hyperopt` to answer the question below.
#
# Note: Don't use autologging for this exercise.
#
# The idea is to just log the information that you need to answer the question below, including:
#
# * the list of hyperparameters that are passed to the `objective` function during the optimization,
# * the RMSE obtained on the validation set (February 2023 data).
#
# What's the best validation RMSE that you got?
#
# * 4.817
# * 5.335
# * 5.818
# * 6.336

# %%
# !python hpo.py
# Out:
#   0%|          | 0/15 [00:00<?, ?trial/s, best loss=?]
#
# 🏃 View run random-forest-hyperopt at: http://127.0.0.1:5000/#/experiments/1/runs/13cafe68ff36402aa92640c0238959eb
#
#
#   0%|          | 0/15 [00:17<?, ?trial/s, best loss=?]
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
#
#   0%|          | 0/15 [00:17<?, ?trial/s, best loss=?]
#   7%|▋         | 1/15 [00:17<04:00, 17.18s/trial, best loss: 5.370086069268862]
#
# 🏃 View run random-forest-hyperopt at: http://127.0.0.1:5000/#/experiments/1/runs/05ce7cd7d83244e3b00439ecef35a39a
#
#
#   7%|▋         | 1/15 [00:18<04:00, 17.18s/trial, best loss: 5.370086069268862]
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
#
#   7%|▋         | 1/15 [00:18<04:00, 17.18s/trial, best loss: 5.370086069268862]
#  13%|█▎        | 2/15 [00:18<01:38,  7.60s/trial, best loss: 5.370086069268862]
#
# 🏃 View run random-forest-hyperopt at: http://127.0.0.1:5000/#/experiments/1/runs/1d48415cd192464db3491dc10883b7be
#
#
#  13%|█▎        | 2/15 [00:19<01:38,  7.60s/trial, best loss: 5.370086069268862]
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
#
#  13%|█▎        | 2/15 [00:19<01:38,  7.60s/trial, best loss: 5.370086069268862]
#  20%|██        | 3/15 [00:19<00:57,  4.82s/trial, best loss: 5.370086069268862]
#
# 🏃 View run random-forest-hyperopt at: http://127.0.0.1:5000/#/experiments/1/runs/87310bba3d4b4cb39ccda479c11eb0bf
#
#
#  20%|██        | 3/15 [00:31<00:57,  4.82s/trial, best loss: 5.370086069268862]
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
#
#  20%|██        | 3/15 [00:31<00:57,  4.82s/trial, best loss: 5.370086069268862]
#  27%|██▋       | 4/15 [00:31<01:23,  7.61s/trial, best loss: 5.357490752366866]
#
# 🏃 View run random-forest-hyperopt at: http://127.0.0.1:5000/#/experiments/1/runs/6ad3c336148840488656021a3865fdb1
#
#
#  27%|██▋       | 4/15 [00:37<01:23,  7.61s/trial, best loss: 5.357490752366866]
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
#
#  27%|██▋       | 4/15 [00:37<01:23,  7.61s/trial, best loss: 5.357490752366866]
#  33%|███▎      | 5/15 [00:37<01:11,  7.15s/trial, best loss: 5.357490752366866]
#
# 🏃 View run random-forest-hyperopt at: http://127.0.0.1:5000/#/experiments/1/runs/a055a15706b840d2bebe45a0d2445175
#
#
#  33%|███▎      | 5/15 [00:59<01:11,  7.15s/trial, best loss: 5.357490752366866]
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
#
#  33%|███▎      | 5/15 [00:59<01:11,  7.15s/trial, best loss: 5.357490752366866]
#  40%|████      | 6/15 [00:59<01:49, 12.21s/trial, best loss: 5.354695072530291]
#
# 🏃 View run random-forest-hyperopt at: http://127.0.0.1:5000/#/experiments/1/runs/56e2d2c7dd1843cfb94c141587bd3bd2
#
#
#  40%|████      | 6/15 [01:19<01:49, 12.21s/trial, best loss: 5.354695072530291]
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
#
#  40%|████      | 6/15 [01:19<01:49, 12.21s/trial, best loss: 5.354695072530291]
#  47%|████▋     | 7/15 [01:19<01:57, 14.63s/trial, best loss: 5.354695072530291]
#
# 🏃 View run random-forest-hyperopt at: http://127.0.0.1:5000/#/experiments/1/runs/4c6ede28be26440a9e1461477d231dff
#
#
#  47%|████▋     | 7/15 [01:21<01:57, 14.63s/trial, best loss: 5.354695072530291]
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
#
#  47%|████▋     | 7/15 [01:21<01:57, 14.63s/trial, best loss: 5.354695072530291]
#  53%|█████▎    | 8/15 [01:21<01:15, 10.77s/trial, best loss: 5.354695072530291]
#
# 🏃 View run random-forest-hyperopt at: http://127.0.0.1:5000/#/experiments/1/runs/929ae5dab65e497f9f9f503cb47cc4e2
#
#
#  53%|█████▎    | 8/15 [01:34<01:15, 10.77s/trial, best loss: 5.354695072530291]
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
#
#  53%|█████▎    | 8/15 [01:34<01:15, 10.77s/trial, best loss: 5.354695072530291]
#  60%|██████    | 9/15 [01:34<01:08, 11.42s/trial, best loss: 5.354695072530291]
#
# 🏃 View run random-forest-hyperopt at: http://127.0.0.1:5000/#/experiments/1/runs/1fa4b86761d24c74be7afab141f4608a
#
#
#  60%|██████    | 9/15 [01:45<01:08, 11.42s/trial, best loss: 5.354695072530291]
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
#
#  60%|██████    | 9/15 [01:45<01:08, 11.42s/trial, best loss: 5.354695072530291]
#  67%|██████▋   | 10/15 [01:45<00:55, 11.10s/trial, best loss: 5.354695072530291]
#
# 🏃 View run random-forest-hyperopt at: http://127.0.0.1:5000/#/experiments/1/runs/1530f626eae24b4cb795157db29685c0
#
#
#  67%|██████▋   | 10/15 [01:53<00:55, 11.10s/trial, best loss: 5.354695072530291]
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
#
#  67%|██████▋   | 10/15 [01:53<00:55, 11.10s/trial, best loss: 5.354695072530291]
#  73%|███████▎  | 11/15 [01:53<00:41, 10.36s/trial, best loss: 5.335419588556921]
#
# 🏃 View run random-forest-hyperopt at: http://127.0.0.1:5000/#/experiments/1/runs/9fb4b935dca34dfe91d4dae20ffe69b5
#
#
#  73%|███████▎  | 11/15 [02:00<00:41, 10.36s/trial, best loss: 5.335419588556921]
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
#
#  73%|███████▎  | 11/15 [02:00<00:41, 10.36s/trial, best loss: 5.335419588556921]
#  80%|████████  | 12/15 [02:00<00:28,  9.34s/trial, best loss: 5.335419588556921]
#
# 🏃 View run random-forest-hyperopt at: http://127.0.0.1:5000/#/experiments/1/runs/616e783cf48140938e39166c3ab9d799
#
#
#  80%|████████  | 12/15 [02:03<00:28,  9.34s/trial, best loss: 5.335419588556921]
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
#
#  80%|████████  | 12/15 [02:03<00:28,  9.34s/trial, best loss: 5.335419588556921]
#  87%|████████▋ | 13/15 [02:03<00:14,  7.29s/trial, best loss: 5.335419588556921]
#
# 🏃 View run random-forest-hyperopt at: http://127.0.0.1:5000/#/experiments/1/runs/3ad5412c943d4f7da199169569d62a3e
#
#
#  87%|████████▋ | 13/15 [02:10<00:14,  7.29s/trial, best loss: 5.335419588556921]
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
#
#  87%|████████▋ | 13/15 [02:10<00:14,  7.29s/trial, best loss: 5.335419588556921]
#  93%|█████████▎| 14/15 [02:10<00:07,  7.29s/trial, best loss: 5.335419588556921]
#
# 🏃 View run random-forest-hyperopt at: http://127.0.0.1:5000/#/experiments/1/runs/e559f41b6f2a4a718ffc9ecd1d380b64
#
#
#  93%|█████████▎| 14/15 [02:21<00:07,  7.29s/trial, best loss: 5.335419588556921]
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
#
#  93%|█████████▎| 14/15 [02:21<00:07,  7.29s/trial, best loss: 5.335419588556921]
# 100%|██████████| 15/15 [02:21<00:00,  8.47s/trial, best loss: 5.335419588556921]
# 100%|██████████| 15/15 [02:21<00:00,  9.46s/trial, best loss: 5.335419588556921]
# 2025/05/26 22:57:34 INFO mlflow.tracking.fluent: Experiment with name 'random-forest-hyperopt' does not exist. Creating a new experiment.

# %% [markdown]
# best loss: 5.335419588556921

# %% [markdown]
# ## Q6. Promote the best model to the model registry
#
# The results from the hyperparameter optimization are quite good. So, we can assume that we are ready to test some of these models in production.
# In this exercise, you'll promote the best model to the model registry. We have prepared a script called `register_model.py`, which will check the results from the previous step and select the top 5 runs.
# After that, it will calculate the RMSE of those models on the test set (March 2023 data) and save the results to a new experiment called `random-forest-best-models`.
#
# Your task is to update the script `register_model.py` so that it selects the model with the lowest RMSE on the test set and registers it to the model registry.
#
# Tip 1: you can use the method `search_runs` from the `MlflowClient` to get the model with the lowest RMSE,
#
# Tip 2: to register the model you can use the method `mlflow.register_model` and you will need to pass the right `model_uri` in the form of a string that looks like this: `"runs:/<RUN_ID>/model"`, and the name of the model (make sure to choose a good one!).
#
# What is the test RMSE of the best model?
#
# * 5.060
# * 5.567
# * 6.061
# * 6.568

# %%
# !python register_model.py --data_path ./output --top_n 5
# Out:
# 🏃 View run secretive-crow-553 at: http://127.0.0.1:5000/#/experiments/2/runs/f59c71d5987147d39e0459852fab0429
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# 🏃 View run persistent-crab-672 at: http://127.0.0.1:5000/#/experiments/2/runs/bcf51043ec914d83b8a1228188b2164e
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# 🏃 View run bittersweet-fox-554 at: http://127.0.0.1:5000/#/experiments/2/runs/cd0f0da84a5c47b9adf687d9b544150a
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# 🏃 View run serious-cow-683 at: http://127.0.0.1:5000/#/experiments/2/runs/218e25804f88468ca794109ddcd71e88
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# 🏃 View run capricious-stag-826 at: http://127.0.0.1:5000/#/experiments/2/runs/0bdb8e29c6e84eca99405a8fbd3a5724
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# 2025/05/26 23:01:03 INFO mlflow.tracking.fluent: Experiment with name 'random-forest-best-models' does not exist. Creating a new experiment.
# Successfully registered model 'best-random-forest-model'.
# 2025/05/26 23:03:48 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: best-random-forest-model, version 1
# Created version '1' of model 'best-random-forest-model'.
#   0%|          | 0/15 [00:00<?, ?trial/s, best loss=?]
#
# 🏃 View run random-forest-hyperopt at: http://127.0.0.1:5000/#/experiments/1/runs/4bb1bfa26b754a1995e7835d6c8be54c
#
#
#   0%|          | 0/15 [19:20<?, ?trial/s, best loss=?]
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
#
#   0%|          | 0/15 [19:20<?, ?trial/s, best loss=?]
#   7%|▋         | 1/15 [19:20<4:30:42, 1160.15s/trial, best loss: 5.080919235745394]
#
# 🏃 View run random-forest-hyperopt at: http://127.0.0.1:5000/#/experiments/1/runs/a01ca53f7ac4454a9b75f6bdb1861d39
#
#
#   7%|▋         | 1/15 [20:02<4:30:42, 1160.15s/trial, best loss: 5.080919235745394]
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
#
#   7%|▋         | 1/15 [20:02<4:30:42, 1160.15s/trial, best loss: 5.080919235745394]
#  13%|█▎        | 2/15 [20:02<1:48:53, 502.54s/trial, best loss: 5.080919235745394]
#
# 🏃 View run random-forest-hyperopt at: http://127.0.0.1:5000/#/experiments/1/runs/5d9353cd738241e88f4fedf7d3ad8029
#
#
#  13%|█▎        | 2/15 [21:00<1:48:53, 502.54s/trial, best loss: 5.080919235745394]
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
#
#  13%|█▎        | 2/15 [21:00<1:48:53, 502.54s/trial, best loss: 5.080919235745394]
#  20%|██        | 3/15 [21:00<59:55, 299.64s/trial, best loss: 5.080919235745394]
#
# 🏃 View run random-forest-hyperopt at: http://127.0.0.1:5000/#/experiments/1/runs/1551ae4e03b7481680289bc78a7fc770
#
#
#  20%|██        | 3/15 [32:01<59:55, 299.64s/trial, best loss: 5.080919235745394]
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
#
#  20%|██        | 3/15 [32:01<59:55, 299.64s/trial, best loss: 5.080919235745394]
#  27%|██▋       | 4/15 [32:01<1:21:03, 442.18s/trial, best loss: 5.0732468909873205]
#
# 🏃 View run random-forest-hyperopt at: http://127.0.0.1:5000/#/experiments/1/runs/e28977c32ac34ace972d37a7f4de0ff9
#
#
#  27%|██▋       | 4/15 [37:35<1:21:03, 442.18s/trial, best loss: 5.0732468909873205]
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
#
#  27%|██▋       | 4/15 [37:35<1:21:03, 442.18s/trial, best loss: 5.0732468909873205]
#  33%|███▎      | 5/15 [37:35<1:07:13, 403.36s/trial, best loss: 5.0732468909873205]
#  33%|███▎      | 5/15 [7:46:35<15:33:11, 5599.19s/trial, best loss: 5.0732468909873205]
# job exception: RESOURCE_DOES_NOT_EXIST: Run with id=d268e911a81c4ab38602d649c33d0d59 not found
#
# Traceback (most recent call last):
#   File "c:\Users\cachu\OneDrive\Documents\MCPI\Tesis_MCPI\Cursos\MLOps-Zoomcamp\02-experiment-tracking\Homework\hpo.py", line 44, in objective
#     mlflow.log_metric("rmse", rmse)
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\mlflow\tracking\fluent.py", line 923, in log_metric
#     return MlflowClient().log_metric(
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\mlflow\tracking\client.py", line 1972, in log_metric
#     return self._tracking_client.log_metric(
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\mlflow\tracking\_tracking_service\client.py", line 672, in log_metric
#     self.store.log_metric(run_id, metric)
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\mlflow\store\tracking\rest_store.py", line 526, in log_metric
#     self._call_endpoint(LogMetric, req_body)
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\mlflow\store\tracking\rest_store.py", line 90, in _call_endpoint
#     return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\mlflow\utils\rest_utils.py", line 402, in call_endpoint
#     response = verify_rest_response(response, endpoint)
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\mlflow\utils\rest_utils.py", line 259, in verify_rest_response
#     raise RestException(json.loads(response.text))
# mlflow.exceptions.RestException: RESOURCE_DOES_NOT_EXIST: Run with id=d268e911a81c4ab38602d649c33d0d59 not found
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\cachu\OneDrive\Documents\MCPI\Tesis_MCPI\Cursos\MLOps-Zoomcamp\02-experiment-tracking\Homework\hpo.py", line 68, in <module>
#     run_optimization()
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\click\core.py", line 1442, in __call__
#     return self.main(*args, **kwargs)
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\click\core.py", line 1363, in main
#     rv = self.invoke(ctx)
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\click\core.py", line 1226, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\click\core.py", line 794, in invoke
#     return callback(*args, **kwargs)
#   File "c:\Users\cachu\OneDrive\Documents\MCPI\Tesis_MCPI\Cursos\MLOps-Zoomcamp\02-experiment-tracking\Homework\hpo.py", line 57, in run_optimization
#     fmin(
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\hyperopt\fmin.py", line 540, in fmin
#     return trials.fmin(
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\hyperopt\base.py", line 671, in fmin
#     return fmin(
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\hyperopt\fmin.py", line 586, in fmin
#     rval.exhaust()
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\hyperopt\fmin.py", line 364, in exhaust
#     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\hyperopt\fmin.py", line 300, in run
#     self.serial_evaluate()
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\hyperopt\fmin.py", line 178, in serial_evaluate
#     result = self.domain.evaluate(spec, ctrl)
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\hyperopt\base.py", line 892, in evaluate
#     rval = self.fn(pyll_rval)
#   File "c:\Users\cachu\OneDrive\Documents\MCPI\Tesis_MCPI\Cursos\MLOps-Zoomcamp\02-experiment-tracking\Homework\hpo.py", line 38, in objective
#     with mlflow.start_run(run_name="random-forest-hyperopt"):
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\mlflow\tracking\fluent.py", line 229, in __exit__
#     end_run(RunStatus.to_string(status))
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\mlflow\tracking\fluent.py", line 519, in end_run
#     MlflowClient().set_terminated(last_active_run_id, status)
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\mlflow\tracking\client.py", line 3355, in set_terminated
#     self._tracking_client.set_terminated(run_id, status, end_time)
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\mlflow\tracking\_tracking_service\client.py", line 1034, in set_terminated
#     self._log_url(run_id)
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\mlflow\tracking\_tracking_service\client.py", line 1008, in _log_url
#     run_info = self.store.get_run(run_id).info
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\mlflow\store\tracking\rest_store.py", line 177, in get_run
#     response_proto = self._call_endpoint(GetRun, req_body)
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\mlflow\store\tracking\rest_store.py", line 90, in _call_endpoint
#     return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\mlflow\utils\rest_utils.py", line 402, in call_endpoint
#     response = verify_rest_response(response, endpoint)
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\mlflow\utils\rest_utils.py", line 259, in verify_rest_response
#     raise RestException(json.loads(response.text))
# mlflow.exceptions.RestException: RESOURCE_DOES_NOT_EXIST: Run with id=d268e911a81c4ab38602d649c33d0d59 not found
# 🏃 View run caring-cub-985 at: http://127.0.0.1:5000/#/experiments/2/runs/3038623bae6a49c7a35544c07539abc2
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# 2025/05/26 15:53:42 INFO mlflow.tracking.fluent: Experiment with name 'random-forest-best-models' does not exist. Creating a new experiment.
# 2025/05/26 15:53:44 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: Unable to allocate 489. GiB for an array with shape (3009173, 21802) and data type float64
# 2025/05/26 22:50:35 WARNING mlflow.sklearn: Failed to log evaluation dataset information to MLflow Tracking. Reason: Unable to allocate 464. GiB for an array with shape (2855951, 21802) and data type float64
# 2025/05/26 22:50:45 WARNING mlflow.sklearn: Failed to log evaluation dataset information to MLflow Tracking. Reason: Unable to allocate 539. GiB for an array with shape (3316216, 21802) and data type float64
# 2025/05/26 22:50:45 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: Unable to allocate 489. GiB for an array with shape (3009173, 21802) and data type float64
# 2025/05/26 23:06:26 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: RESOURCE_DOES_NOT_EXIST: Run with id=95f9d6014c774f2c8587fb6646442c09 not found
# Traceback (most recent call last):
#   File "c:\Users\cachu\OneDrive\Documents\MCPI\Tesis_MCPI\Cursos\MLOps-Zoomcamp\02-experiment-tracking\Homework\register_model.py", line 40, in train_and_log_model
#     mlflow.log_metric("val_rmse", val_rmse)
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\mlflow\tracking\fluent.py", line 923, in log_metric
#     return MlflowClient().log_metric(
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\mlflow\tracking\client.py", line 1972, in log_metric
#     return self._tracking_client.log_metric(
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\mlflow\tracking\_tracking_service\client.py", line 672, in log_metric
#     self.store.log_metric(run_id, metric)
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\mlflow\store\tracking\rest_store.py", line 526, in log_metric
#     self._call_endpoint(LogMetric, req_body)
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\mlflow\store\tracking\rest_store.py", line 90, in _call_endpoint
#     return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\mlflow\utils\rest_utils.py", line 402, in call_endpoint
#     response = verify_rest_response(response, endpoint)
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\mlflow\utils\rest_utils.py", line 259, in verify_rest_response
#     raise RestException(json.loads(response.text))
# mlflow.exceptions.RestException: RESOURCE_DOES_NOT_EXIST: Run with id=95f9d6014c774f2c8587fb6646442c09 not found
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\cachu\OneDrive\Documents\MCPI\Tesis_MCPI\Cursos\MLOps-Zoomcamp\02-experiment-tracking\Homework\register_model.py", line 88, in <module>
#     run_register_model()
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\click\core.py", line 1442, in __call__
#     return self.main(*args, **kwargs)
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\click\core.py", line 1363, in main
#     rv = self.invoke(ctx)
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\click\core.py", line 1226, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\click\core.py", line 794, in invoke
#     return callback(*args, **kwargs)
#   File "c:\Users\cachu\OneDrive\Documents\MCPI\Tesis_MCPI\Cursos\MLOps-Zoomcamp\02-experiment-tracking\Homework\register_model.py", line 70, in run_register_model
#     train_and_log_model(data_path=data_path, params=run.data.params)
#   File "c:\Users\cachu\OneDrive\Documents\MCPI\Tesis_MCPI\Cursos\MLOps-Zoomcamp\02-experiment-tracking\Homework\register_model.py", line 30, in train_and_log_model
#     with mlflow.start_run():
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\mlflow\tracking\fluent.py", line 229, in __exit__
#     end_run(RunStatus.to_string(status))
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\mlflow\tracking\fluent.py", line 519, in end_run
#     MlflowClient().set_terminated(last_active_run_id, status)
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\mlflow\tracking\client.py", line 3355, in set_terminated
#     self._tracking_client.set_terminated(run_id, status, end_time)
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\mlflow\tracking\_tracking_service\client.py", line 1034, in set_terminated
#     self._log_url(run_id)
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\mlflow\tracking\_tracking_service\client.py", line 1008, in _log_url
#     run_info = self.store.get_run(run_id).info
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\mlflow\store\tracking\rest_store.py", line 177, in get_run
#     response_proto = self._call_endpoint(GetRun, req_body)
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\mlflow\store\tracking\rest_store.py", line 90, in _call_endpoint
#     return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\mlflow\utils\rest_utils.py", line 402, in call_endpoint
#     response = verify_rest_response(response, endpoint)
#   File "c:\Users\cachu\anaconda3\envs\powerfull_gpu\lib\site-packages\mlflow\utils\rest_utils.py", line 259, in verify_rest_response
#     raise RestException(json.loads(response.text))
# mlflow.exceptions.RestException: RESOURCE_DOES_NOT_EXIST: Run with id=95f9d6014c774f2c8587fb6646442c09 not found

# %% [markdown]
# ![image.png](attachment:image.png)
